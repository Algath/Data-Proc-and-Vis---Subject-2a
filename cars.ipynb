# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/nhtsa_vehicle_safety_recall_intelligence_ultimate.csv')

df.head()
# Out:
#         record_id  nhtsa_record_id recall_campaign_id  \
# 0  835d8908b3a39d           105867          14V400000
# 1  1e393b1efc0ea4           105872          14V400000
# 2  1ea55f8d43bf01           105885          14V400000
# 3  3588d2734c086b           105883          14V400000
# 4  ab8db036507579           105882          14V400000
#
#   manufacturer_campaign_id vehicle_make   vehicle_model  vehicle_year  \
# 0                    14350   OLDSMOBILE        INTRIGUE        1998.0
# 1                    14350    CHEVROLET  MALIBU CLASSIC        2005.0
# 2                    14350   OLDSMOBILE           ALERO        2001.0
# 3                    14350      PONTIAC        GRAND AM        2000.0
# 4                    14350      PONTIAC        GRAND AM        2002.0
#
#    vehicle_year_num vehicle_era   manufacturer_name  ...  \
# 0            1998.0       1990s  General Motors LLC  ...
# 1            2005.0       2000s  General Motors LLC  ...
# 2            2001.0       2000s  General Motors LLC  ...
# 3            2000.0       2000s  General Motors LLC  ...
# 4            2002.0       2000s  General Motors LLC  ...
#
#                                           source_url scrape_date  \
# 0  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 1  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 2  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 3  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 4  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
#
#   dataset_version record_creation_date              RCL_CMPT_ID MFR_COMP_NAME  \
# 0            v1.0             20140707  56617000202679000000212           NaN
# 1            v1.0             20140707  56617000204360000000212           NaN
# 2            v1.0             20140707  56617000202733000000212           NaN
# 3            v1.0             20140707  56617000202623000000212           NaN
# 4            v1.0             20140707  56617000202625000000212           NaN
#
#    MFR_COMP_DESC MFR_COMP_PTNO creation_date_parsed  defect_severity_score
# 0            NaN           NaN           2014-07-07                 0.3979
# 1            NaN           NaN           2014-07-07                 0.3979
# 2            NaN           NaN           2014-07-07                 0.3979
# 3            NaN           NaN           2014-07-07                 0.3979
# 4            NaN           NaN           2014-07-07                 0.3979
#
# [5 rows x 53 columns]

# %% [markdown]
# # Pre-processing

# %%
recall = df['recall_type_label'].unique()
recall
# Out:
# <StringArray>
# ['Vehicle', 'Equipment', 'Child Seat', 'Tire']
# Length: 4, dtype: str

# %%
df = df[df['recall_type_label'].isin(['Vehicle'])]
df.head()
# Out:
#         record_id  nhtsa_record_id recall_campaign_id  \
# 0  835d8908b3a39d           105867          14V400000
# 1  1e393b1efc0ea4           105872          14V400000
# 2  1ea55f8d43bf01           105885          14V400000
# 3  3588d2734c086b           105883          14V400000
# 4  ab8db036507579           105882          14V400000
#
#   manufacturer_campaign_id vehicle_make   vehicle_model  vehicle_year  \
# 0                    14350   OLDSMOBILE        INTRIGUE        1998.0
# 1                    14350    CHEVROLET  MALIBU CLASSIC        2005.0
# 2                    14350   OLDSMOBILE           ALERO        2001.0
# 3                    14350      PONTIAC        GRAND AM        2000.0
# 4                    14350      PONTIAC        GRAND AM        2002.0
#
#    vehicle_year_num vehicle_era   manufacturer_name  ...  \
# 0            1998.0       1990s  General Motors LLC  ...
# 1            2005.0       2000s  General Motors LLC  ...
# 2            2001.0       2000s  General Motors LLC  ...
# 3            2000.0       2000s  General Motors LLC  ...
# 4            2002.0       2000s  General Motors LLC  ...
#
#                                           source_url scrape_date  \
# 0  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 1  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 2  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 3  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 4  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
#
#   dataset_version record_creation_date              RCL_CMPT_ID MFR_COMP_NAME  \
# 0            v1.0             20140707  56617000202679000000212           NaN
# 1            v1.0             20140707  56617000204360000000212           NaN
# 2            v1.0             20140707  56617000202733000000212           NaN
# 3            v1.0             20140707  56617000202623000000212           NaN
# 4            v1.0             20140707  56617000202625000000212           NaN
#
#    MFR_COMP_DESC MFR_COMP_PTNO creation_date_parsed  defect_severity_score
# 0            NaN           NaN           2014-07-07                 0.3979
# 1            NaN           NaN           2014-07-07                 0.3979
# 2            NaN           NaN           2014-07-07                 0.3979
# 3            NaN           NaN           2014-07-07                 0.3979
# 4            NaN           NaN           2014-07-07                 0.3979
#
# [5 rows x 53 columns]

# %%
components = df['component_category'].unique()
components
# Out:
# <StringArray>
# [            'Air Bag', 'Engine / Powertrain',          'Electrical',
#               'Brakes',            'Steering',         'Fuel System',
#                'Other',      'Tires / Wheels',          'Visibility',
#            'Fire Risk',          'Suspension',          'Seat Belts',
#        'Software / EV',          'Child Seat']
# Length: 14, dtype: str

# %%
df = df[~df['component_category'].isin(['Child Seat', 'Other'])]
df.head()
# Out:
#         record_id  nhtsa_record_id recall_campaign_id  \
# 0  835d8908b3a39d           105867          14V400000
# 1  1e393b1efc0ea4           105872          14V400000
# 2  1ea55f8d43bf01           105885          14V400000
# 3  3588d2734c086b           105883          14V400000
# 4  ab8db036507579           105882          14V400000
#
#   manufacturer_campaign_id vehicle_make   vehicle_model  vehicle_year  \
# 0                    14350   OLDSMOBILE        INTRIGUE        1998.0
# 1                    14350    CHEVROLET  MALIBU CLASSIC        2005.0
# 2                    14350   OLDSMOBILE           ALERO        2001.0
# 3                    14350      PONTIAC        GRAND AM        2000.0
# 4                    14350      PONTIAC        GRAND AM        2002.0
#
#    vehicle_year_num vehicle_era   manufacturer_name  ...  \
# 0            1998.0       1990s  General Motors LLC  ...
# 1            2005.0       2000s  General Motors LLC  ...
# 2            2001.0       2000s  General Motors LLC  ...
# 3            2000.0       2000s  General Motors LLC  ...
# 4            2002.0       2000s  General Motors LLC  ...
#
#                                           source_url scrape_date  \
# 0  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 1  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 2  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 3  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
# 4  https://static.nhtsa.gov/odi/ffdd/rcl/FLAT_RCL...  2026-04-21
#
#   dataset_version record_creation_date              RCL_CMPT_ID MFR_COMP_NAME  \
# 0            v1.0             20140707  56617000202679000000212           NaN
# 1            v1.0             20140707  56617000204360000000212           NaN
# 2            v1.0             20140707  56617000202733000000212           NaN
# 3            v1.0             20140707  56617000202623000000212           NaN
# 4            v1.0             20140707  56617000202625000000212           NaN
#
#    MFR_COMP_DESC MFR_COMP_PTNO creation_date_parsed  defect_severity_score
# 0            NaN           NaN           2014-07-07                 0.3979
# 1            NaN           NaN           2014-07-07                 0.3979
# 2            NaN           NaN           2014-07-07                 0.3979
# 3            NaN           NaN           2014-07-07                 0.3979
# 4            NaN           NaN           2014-07-07                 0.3979
#
# [5 rows x 53 columns]

# %%
manufacturer_campaign_ids = df['manufacturer_campaign_id'].unique()
vehicle_year = df['vehicle_year'].unique()
vehicle_year_num = df['vehicle_year_num'].unique()
vehicle_era = df['vehicle_era'].unique()

print(manufacturer_campaign_ids)
print(vehicle_year)
print(vehicle_year_num)
print(vehicle_era)

df = df.dropna()
# Out:
# <StringArray>
# [          '14350',          '17-307',           '8715J',             '251',
#            'SC098',             'C0M',     '14113,14133',             'P25',
#                nan,           'R22C8',
#  ...
#           '20TA06', '21TB10 / 21TA10',        'R20AM-SB',      'N212346640',
#  'Bulletin 2020-5',        'RC000204',        'RVXX2005',            'N494',
#           'TB2011',           'V2003']
# Length: 3560, dtype: str
# [1998. 2005. 2001. 2000. 2002. 2003. 2004. 1999. 1997. 2006. 2007. 2008.
#  2014. 2010. 1993. 2011. 2016. 2013. 2017. 2015. 2009. 2012. 2018. 1989.
#  2020. 2019. 2021. 2022. 2023. 1996. 1994. 1995. 2024. 1991. 1992. 1990.
#  2025. 2026. 1988. 2027.   nan]
# [1998. 2005. 2001. 2000. 2002. 2003. 2004. 1999. 1997. 2006. 2007. 2008.
#  2014. 2010. 1993. 2011. 2016. 2013. 2017. 2015. 2009. 2012. 2018. 1989.
#  2020. 2019. 2021. 2022. 2023. 1996. 1994. 1995. 2024. 1991. 1992. 1990.
#  2025. 2026. 1988. 2027.   nan]
# <StringArray>
# ['1990s', '2000s', '2010s', '1980s', '2020s', nan]
# Length: 6, dtype: str

# %% [markdown]
# # Analyse

# %%
defect_severity = df['defect_severity'].unique()

defect_severity_by_component = df.groupby('component_category')['defect_severity'].value_counts().unstack().fillna(0)
defect_severity_by_component.plot(kind='bar', stacked=True)
plt.title('Defect Severity by Component Category')
plt.xlabel('Component Category')
plt.ylabel('Count')
plt.legend(title='Defect Severity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
defect_severity = df['defect_severity'].unique()
defect_severity
# Out:
# <StringArray>
# ['HIGH', 'MEDIUM', 'CRITICAL', 'LOW']
# Length: 4, dtype: str

# %%
defect_severity_by_component_years = (
    df.groupby(['vehicle_year_num', 'component_category'])['defect_severity']
    .value_counts()
    .unstack()
    .fillna(0)
)

severity_colors = {
    'CRITICAL': '#d32f2f',
    'HIGH':     '#f57c00',
    'MEDIUM':   '#fbc02d',
    'LOW':      '#388e3c',
}

components = defect_severity_by_component_years.index.get_level_values(1).unique()
n_rows = (len(components) + 1) // 2

fig, ax = plt.subplots(n_rows, 2, figsize=(14, 4 * n_rows))
ax = ax.flatten()

for i, component in enumerate(components):
    data = defect_severity_by_component_years.xs(component, level=1)
    colors = [severity_colors.get(col, '#90a4ae') for col in data.columns]
    data.plot(kind='bar', stacked=True, ax=ax[i], color=colors)
    ax[i].set_title(f'Defect Severity for {component}')
    ax[i].set_xlabel('Vehicle Year')
    ax[i].set_ylabel('Count')
    ax[i].legend(title='Defect Severity')

for j in range(len(components), len(ax)):
    ax[j].set_visible(False)

plt.tight_layout()
plt.show()
